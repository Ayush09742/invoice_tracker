# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime
import scipy.stats as st
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 import random
#       4 import matplotlib.pyplot as plt
# ----> 5 import seaborn as sns
#       6 import datetime as datetime
#       7 import scipy.stats as st
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\relational.py:17
#       8 from ._oldcore import (
#       9     VectorPlotter,
#      10 )
#      11 from .utils import (
#      12     locator_to_legend_entries,
#      13     adjust_legend_subtitles,
#      14     _default_color,
#      15     _deprecate_ci,
#      16 )
# ---> 17 from ._statistics import EstimateAggregator
#      18 from .axisgrid import FacetGrid, _facet_docs
#      19 from ._docstrings import DocstringComponents, _core_docs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_statistics.py:31
#      29 import pandas as pd
#      30 try:
# ---> 31     from scipy.stats import gaussian_kde
#      32     _no_scipy = False
#      33 except ImportError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\__init__.py:628
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    623
#     624 """  # noqa: E501
#     626 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     627                                DegenerateDataWarning, FitError)
# --> 628 from ._stats_py import *
#     629 from ._variation import variation
#     630 from .distributions import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_stats_py.py:49
#      46 # Import unused here but needs to stay until end of deprecation periode
#      47 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      48 from scipy import linalg  # noqa: F401
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#      52 from ._stats_mstats_common import theilslopes, siegelslopes
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)      6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:194
#     190     def _isf(self, q, n):
#     191         return sc.smirnovi(n, q)
# --> 194 ksone = ksone_gen(a=0.0, b=1.0, name='ksone')
#     197 class kstwo_gen(rv_continuous):
#     198     r"""Kolmogorov-Smirnov two-sided test statistic distribution.
#     199
#     200     This is the distribution of the two-sided Kolmogorov-Smirnov (KS)
#    (...)    262
#     263     """
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_distn_infrastructure.py:1878, in rv_continuous.__init__(self, momtype, a, b, xtol, badvalue, name, longname, shapes, seed)
#    1874 def __init__(self, momtype=1, a=None, b=None, xtol=1e-14,
#    1875              badvalue=None, name=None, longname=None,
#    1876              shapes=None, seed=None):
# -> 1878     super().__init__(seed)
#    1880     # save the ctor parameters, cf generic freeze
#    1881     self._ctor_param = dict(
#    1882         momtype=momtype, a=a, b=b, xtol=xtol,
#    1883         badvalue=badvalue, name=name, longname=longname,
#    1884         shapes=shapes, seed=seed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_distn_infrastructure.py:694, in rv_generic.__init__(self, seed)
#     690 sig = _getfullargspec(self._stats)
#     691 self._stats_has_moments = ((sig.varkw is not None) or
#     692                            ('moments' in sig.args) or
#     693                            ('moments' in sig.kwonlyargs))
# --> 694 self._random_state = check_random_state(seed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\_lib\_util.py:413, in check_random_state(seed)
#     394 """Turn `seed` into a `np.random.RandomState` instance.
#     395
#     396 Parameters
#    (...)    410
#     411 """
#     412 if seed is None or seed is np.random:
# --> 413     return np.random.mtrand._rand
#     414 if isinstance(seed, numbers.Integral | np.integer):
#     415     return np.random.RandomState(seed)
#
# AttributeError: module 'numpy.random' has no attribute 'mtrand'

# %%
df = pd.read_csv(r"C:\Users\ayush\Downloads\fraud detection.zip")

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %%
df['isFlaggedFraud'].value_counts()
